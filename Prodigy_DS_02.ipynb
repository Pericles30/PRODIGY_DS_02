# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
train = pd.read_csv("/Users/pericles/Desktop/p/train copy.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test = pd.read_csv("/Users/pericles/Desktop/p/test.csv")
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
train.groupby('Survived').mean()
# Out:
# /var/folders/bn/jlb56r7s36q53s1xmvmmpsvr0000gn/T/ipykernel_1197/1563225271.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   train.groupby('Survived').mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
train.corr()
# Out:
# /var/folders/bn/jlb56r7s36q53s1xmvmmpsvr0000gn/T/ipykernel_1197/2189804198.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# ...

# %%
males=len(train[train['Sex']=='male'])
males
# Out:
# 577

# %%
females=len(train[train['Sex']=='female'])
females
# Out:
# 314

# %%
fig = plt.figure()
a = fig.add_axes([0,0,1,1])
gender = ['male','female']
index = [577,314]
a.bar(gender,index)
plt.xlabel('Gender')
plt.ylabel('Number of people on boarding')
plt.show()

# %%
alive=len(train[train['Survived']==1])
print("Number of people Alive : ",alive)
# Out:
# Number of people Alive :  342

# %%
dead=len(train[train['Survived']==0])
print("Number of people Dead : ",dead)
# Out:
# Number of people Dead :  549

# %%
train.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
fig = plt.figure()
a = fig.add_axes([0,0,1,1])
status = ['Survived','Dead']
ind = [alive,dead]
a.bar(status,ind)
plt.title('Status')
plt.show()

# %%
test = pd.read_csv("/Users/pericles/Desktop/p/test.csv")
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.describe(include='all')
# Out:
#         PassengerId      Pclass              Name   Sex         Age  \
# count    418.000000  418.000000               418   418  332.000000
# unique          NaN         NaN               418     2         NaN
# top             NaN         NaN  Kelly, Mr. James  male         NaN
# freq            NaN         NaN                 1   266         NaN
# mean    1100.500000    2.265550               NaN   NaN   30.272590
# std      120.810458    0.841838               NaN   NaN   14.181209
# min      892.000000    1.000000               NaN   NaN    0.170000
# 25%      996.250000    1.000000               NaN   NaN   21.000000
# 50%     1100.500000    3.000000               NaN   NaN   27.000000
# 75%     1204.750000    3.000000               NaN   NaN   39.000000
# max     1309.000000    3.000000               NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# ...

# %%
maximum = test['Fare'].max()
maximum
# Out:
# 512.3292

# %%
males=len(test[test['Sex']=='male'])
print("Total Number Of Males :",males)
# Out:
# Total Number Of Males : 266

# %%
female=len(test[test['Sex']=='female'])
print("Total Number Of Females :",female)
# Out:
# Total Number Of Females : 152

# %%
test.groupby('Age').mean()
# Out:
# /var/folders/bn/jlb56r7s36q53s1xmvmmpsvr0000gn/T/ipykernel_1197/3386132596.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   test.groupby('Age').mean()
#        PassengerId  Pclass     SibSp  Parch        Fare
# Age
# 0.17        1246.0     3.0  1.000000    2.0   20.575000
# 0.33        1093.0     3.0  0.000000    2.0   14.400000
# 0.75        1173.0     3.0  1.000000    1.0   13.775000
# 0.83        1199.0     3.0  0.000000    1.0    9.350000
# 0.92        1142.0     2.0  1.000000    2.0   27.750000
# ...            ...     ...       ...    ...         ...
# 62.00        894.0     2.0  0.000000    0.0    9.687500
# 63.00        955.5     1.5  1.000000    0.0  123.889600
# 64.00       1132.0     1.0  0.666667    1.0   61.652767
# 67.00        973.0     1.0  1.000000    0.0  221.779200
# ...

# %%
test.corr()
# Out:
# /var/folders/bn/jlb56r7s36q53s1xmvmmpsvr0000gn/T/ipykernel_1197/4138799845.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   test.corr()
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.026751 -0.034102  0.003818  0.043080  0.008211
# Pclass         -0.026751  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age            -0.034102 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# SibSp           0.003818  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch           0.043080  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare            0.008211 -0.577147  0.337932  0.171539  0.230046  1.000000
